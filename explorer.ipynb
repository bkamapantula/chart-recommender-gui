# %%
import pandas as pd

df = pd.read_excel('flags.xlsx')

# %%
df.dtypes
# Out:
# ID            object
# c1             int64
# c2             int64
# c3             int64
# c4             int64
# c5             int64
# c6             int64
# c7             int64
# c8             int64
# Name          object
# Continent     object
# Symbols       object
# Shapes        object
# Stripes       object
# Cross         object
# Union-Flag    object
# Text          object
# dtype: object

# %%
df
# Out:
#       ID  c1  c2  c3  c4  c5  c6  c7  c8                  Name      Continent  \
# 0    AND  35   1  26   0  32   0   0   4               Andorra         Europe
# 1    ARE  24   0   0  25   0   0  25  24  United Arab Emirates           Asia
# 2    AFG  28   1   0  33   0   0  33   3           Afghanistan           Asia
# 3    ATG  50   0   5   0   0  10  25   7       Antigua Barbuda  North America
# 4    ALB  87   0   0   0   0   0  12   0               Albania         Europe
# 5    ARM  33  33   0   0  33   0   0   0               Armenia           Asia
# 6    AGO  48   0   4   0   0   0  46   0                Angola         Africa
# 7    ARG   0   2   0   0   0  66   0  31             Argentina  South America
# 8    AUT  66   0   0   0   0   0   0  33               Austria         Europe
# 9    AUS   9   0   0   0  79   0   0  11             Australia        Oceania
# 10   AZE  31   0   0  33   0  33   0   1            Azerbaijan           Asia
# ...
